# %%
## if statement
age=20
if age>=18:
    print("You are allowed to vote")
# Out:
# You are allowed to vote

# %%
age>=18
# Out:
# True

# %%
## else
## The else statement executes a block of code if the condition in the if statement is False.

age=16
if age>=18:
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")
# Out:
# You are not eligible to vote

# %%
##elif
## The elif statement allows you to check multiple conditions in sequence.It stands for "else if".

age=17
if age<13:
    print("You are a child.")
elif age<18:
    print("You are a teenager.")
else:
    print("You are an adult.")
# Out:
# You are a teenager.

# %%
## Nested conditional statements
## You can place one or more if, elif, or else statements inside another if, elif, or else statement. This is known as nesting.
## number even,odd,negative

num=int(input("Enter the number"))
if num>=0:
    print("The number is positive")
    if num%2==0:
        print("The number is even")
    else:
        print("The number is odd")
else:
    print("The number is negative")
# Out:
# The number is positive
# The number is even

# %%
## Practical examples
## Determine if a year is a leap year using nested condition statements.

year=int(input("Enter the year"))
if year%4==0:
    if year%100==0:
        if year%400==0:
            print(year, "is a leap year")
        else:
            print(year, "is not a leap year")
    else:
        print(year, "is a leap year")
else:
    print(year, "is not a leap year")
# Out:
# 2022 is not a leap year

# %%
# Assignment
## Simple Calculator program
## Take user input

num1=int(input("Enter first number:"))
num2=int(input("Enter second number:"))
operation=input("Enter operation(=,-,*,/)")

# Perform the requested operation
if operation == "+":
    result=num1+num2
elif operation == "-":
    result=num1-num2
elif operation == "*":
    result=num1*num2
elif operation == "/":
    if num2!=0:
        result=num1/num2
    else:
        result="Error! Division by zero."
else:
    result="Invalid operation"
print("The result is:", result)
# Out:
# The result is: 12

# %%
##Determine the ticket price based on age and whether the person is a student.
## Ticket pricing based on age and student status

## Take user input
age=int(input("Enter your age:"))
is_student=input("Are you a student? (yes/no):").lower()

#Determine tickets price
if age<5:
    price="Free"
elif age<=12:
    price="$10"
elif age<=17:
    if is_student=="yes":
        price="$12"
    else:
        price="$15"
elif age<=64:
    if is_student=="yes":
        price="$18"
    else:
        price="$25"
else:
    price="$20"
print("Your ticket price is:", price)
# Out:
# Your ticket price is: $25
